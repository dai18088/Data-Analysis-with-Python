# %%
import os
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from array import *


#year = int(input('Dwse Etos: '))
first_day = int(input('Dwse Prwth mera: '))
last_day = int(input('Dwse Teleutaia mera: '))

if(first_day <= 9):
    #path = f'home/gnss/GPSDATA/MET_BCKP/CAMP/{year}/{first_day}/CRD/W42200{first_day}L.CRD'
    path = f'2022_CRD/W42200{first_day}L.CRD'
elif(first_day <= 99):
    path = f'2022_CRD/W4220{first_day}L.CRD'
else:
    path= f'2022_CRD/W422{first_day}L.CRD'

df = pd.read_fwf(path, skiprows=4, skipfooter=5) 
StationName1 = []
StationName1 = df[df.columns[1]] 

X1 = []
Y1 = []
Z1 = []

X2 = []
Y2 = []
Z2 = []

AFAL = []
MANO = []
SANT = []
SAWI = []

AFALX = []
AFALY = []
AFALZ = []

MANOX = []
MANOY = []
MANOZ = []

SANTX = []
SANTY = []
SANTZ = []

SAWIX = []
SAWIY = []
SAWIZ = []

DateMiss = []
Dates = []


for i in range(first_day,last_day+1):
    
    #Diabazw to path kai exw 3 periptwseis
    if(i <= 9):
        path1 = f'2022_CRD/W42200{i}L.CRD'
    elif(i <= 99):
        path1 = f'2022_CRD/W4220{i}L.CRD'
    else:
        path1 = f'2022_CRD/W422{i}L.CRD'
    
    #Elegxo an yparxei to arxeio
    isFile1 = os.path.isfile(path1)
    if(isFile1 == False):
        DateMiss.append(i)
    else:
        df1 = pd.read_fwf(path1, skiprows=4, skipfooter=5) 
        Dates.append(i)
            
            
        #Krataw ta Prwta Dedomena Apo to prwto Arxeio
        X1 = df1[df1.columns[2]] 
        Y1 = df1[df1.columns[3]] 
        Z1 = df1[df1.columns[4]] 

        #FOR ΓΙΑ ΝΑ ΔΙΑΒΑΣΕΙ ΔΕΥΤΕΡΟ ΑΡΧΕΙΟ
        for k in range(i+1,last_day):
            if(k <= 9):
                path2 = f'2022_CRD/W42200{k}L.CRD'
            elif(k <= 99):
                path2 = f'2022_CRD/W4220{k}L.CRD'
            else:
                path2 = f'2022_CRD/W422{k}L.CRD'
            
            
            isFile2 = os.path.isfile(path2)
            if(isFile2 == True):
                df2 = pd.read_fwf(path2, skiprows=4, skipfooter=5) 
            
                X2 = df2[df2.columns[2]] 
                Y2 = df2[df2.columns[3]] 
                Z2 = df2[df2.columns[4]]
        
            #Ksekinaw tous ypologismous
            for j in range (0,len(StationName1)):
                if(StationName1[j] == 'AFAL XXXXXXXXX'):
                    if(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2) > 0.15):
                        AFAL.append(0)
                        AFALX.append(0)
                        AFALY.append(0)
                        AFALZ.append(0)
                    else:
                        AFAL.append(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2))
                        AFALX.append(X2[j] - X1[j])
                        AFALY.append(Y2[j] - Y1[j])
                        AFALZ.append(Z2[j] - Z1[j])
                elif (StationName1[j] == 'MANO XXXXXXXXX'):
                    if(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2) > 0.15):
                        MANO.append(0)
                        MANOX.append(0)
                        MANOY.append(0)
                        MANOZ.append(0)
                    else:
                        MANO.append(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2))
                        MANOX.append(X2[j] - X1[j])
                        MANOY.append(Y2[j] - Y1[j])
                        MANOZ.append(Z2[j] - Z1[j])
                elif (StationName1[j] == 'SANT XXXXXXXXX'):
                    if(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2) > 0.15):
                        SANT.append(0)
                        SANTX.append(0)
                        SANTY.append(0)
                        SANTZ.append(0)
                    else:
                        SANT.append(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2))
                        SANTX.append(X2[j] - X1[j])
                        SANTY.append(Y2[j] - Y1[j])
                        SANTZ.append(Z2[j] - Z1[j])
                    
                elif (StationName1[j] == 'SAWI XXXXXXXXX'):
                    if(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2) > 0.15):
                        SAWI.append(0)
                        SAWIX.append(0)
                        SAWIY.append(0)
                        SAWIZ.append(0)
                    else:
                        SAWI.append(math.sqrt((X2[j] - X1[j])**2+(Y2[j] - Y1[j])**2+(Z2[j] - Z1[j])**2))
                        SAWIX.append(X2[j] - X1[j])
                        SAWIY.append(Y2[j] - Y1[j])
                        SAWIZ.append(Z2[j] - Z1[j])
            
            
            #Stamataw thn Deyterh giati exw parei ta dedomena pou xreiazomoun    
            break
        
        
       
            
#ΥΠΟΛΟΓΙΣΜΟΣ DEast,DUp,DNorth ΓΙΑ ΟΛΟΥΣ ΤΟΥΣ ΣΤΑΘΜΟΥΣ
        
AFAL_COORDS = [25.3892295548,36.4608680428,196.1581]
MANO_COORDS = [25.3454148891,36.4356115948,205.9502]
SANT_COORDS = [25.4226156021,36.4335959289,392.0033]
SAWI_COORDS = [25.4370720969,36.3871092752,341.8376]

t_AFAL = []
DEast_AFAL = []
DUp_AFAL = []
DNorth_AFAL = []

lat0_AFAL = math.radians(AFAL_COORDS[1])
lon0_AFAL = math.radians(AFAL_COORDS[0])

for i in range(0,len(AFALX)):
    t_AFAL.append(math.cos(lon0_AFAL) * AFALX[i] + math.sin(lon0_AFAL) * AFALY[i])
    DEast_AFAL.append(-math.sin(lon0_AFAL) * AFALX[i] + math.cos(lon0_AFAL) * AFALY[i])

    DUp_AFAL.append(math.cos(lat0_AFAL) * t_AFAL[i] + math.sin(lat0_AFAL) * AFALZ[i])
    DNorth_AFAL.append(-math.sin(lat0_AFAL) * t_AFAL[i] + math.cos(lat0_AFAL) * AFALZ[i])      

    
t_MANO = []
DEast_MANO = []
DUp_MANO = []
DNorth_MANO = []

lat0_MANO = math.radians(MANO_COORDS[1])
lon0_MANO = math.radians(MANO_COORDS[0])

for i in range(0,len(MANOX)):
    t_MANO.append(math.cos(lon0_MANO) * MANOX[i] + math.sin(lon0_MANO) * MANOY[i])
    DEast_MANO.append(-math.sin(lon0_MANO) * MANOX[i] + math.cos(lon0_MANO) * MANOY[i])

    DUp_MANO.append(math.cos(lat0_MANO) * t_MANO[i] + math.sin(lat0_MANO) * MANOZ[i])
    DNorth_MANO.append(-math.sin(lat0_MANO) * t_MANO[i] + math.cos(lat0_MANO) * MANOZ[i])  
    

t_SANT = []
DEast_SANT = []
DUp_SANT = []
DNorth_SANT = []

lat0_SANT = math.radians(SANT_COORDS[1])
lon0_SANT = math.radians(SANT_COORDS[0])

for i in range(0,len(SANTX)):
    t_SANT.append(math.cos(lon0_SANT) * SANTX[i] + math.sin(lon0_SANT) * SANTY[i])
    DEast_SANT.append(-math.sin(lon0_SANT) * SANTX[i] + math.cos(lon0_SANT) * SANTY[i])

    DUp_SANT.append(math.cos(lat0_SANT) * t_SANT[i] + math.sin(lat0_SANT) * SANTZ[i])
    DNorth_SANT.append(-math.sin(lat0_SANT) * t_SANT[i] + math.cos(lat0_SANT) * SANTZ[i])   

    
t_SAWI = []
DEast_SAWI = []
DUp_SAWI = []
DNorth_SAWI = []

lat0_SAWI = math.radians(SAWI_COORDS[1])
lon0_SAWI = math.radians(SAWI_COORDS[0])

for i in range(0,len(SAWIX)):
    t_SAWI.append(math.cos(lon0_SAWI) * SAWIX[i] + math.sin(lon0_SAWI) * SAWIY[i])
    DEast_SAWI.append(-math.sin(lon0_SAWI) * SAWIX[i] + math.cos(lon0_SAWI) * SAWIY[i])

    DUp_SAWI.append(math.cos(lat0_SAWI) * t_SAWI[i] + math.sin(lat0_SAWI) * SAWIZ[i])
    DNorth_SAWI.append(-math.sin(lat0_SAWI) * t_SAWI[i] + math.cos(lat0_SAWI) * SAWIZ[i]) 
    
    
#ΔΙΑΔΙΚΑΣΙΑ ΥΠΟΛΟΓΙΣΜΟΥ ΔV

AFAL_SOURCE = 3653.73 #Η ΤΙΜΗ ΥΠΟΛΟΓΙΣΗΚΕ ΣΕ m
MANO_SOURCE = 3931.81 #Η ΤΙΜΗ ΥΠΟΛΟΓΙΣΗΚΕ ΣΕ m
SANT_SOURCE = 3146.53 #Η ΤΙΜΗ ΥΠΟΛΟΓΙΣΗΚΕ ΣΕ m
SAWI_SOURCE = 6303.78 #Η ΤΙΜΗ ΥΠΟΛΟΓΙΣΗΚΕ ΣΕ m

F = 4400 #Η ΤΙΜΗ ΥΠΟΛΟΓΙΣΗΚΕ ΣΕ m

K_AFAL = []
K_MANO = []
K_SANT = []
K_SAWI = []

for i in range(0,len(DUp_AFAL)):
    K_AFAL.append(DUp_AFAL[i]*(F**2 + AFAL_SOURCE**2)**(3/2)/F)
    K_MANO.append(DUp_MANO[i]*(F**2 + MANO_SOURCE**2)**(3/2)/F)
    K_SANT.append(DUp_SANT[i]*(F**2 + SANT_SOURCE**2)**(3/2)/F)
    K_SAWI.append(DUp_SAWI[i]*(F**2 + SAWI_SOURCE**2)**(3/2)/F)

#Η ΜΕΤΑΒΟΛΗ ΤΟΥ ΟΓΚΟΥ ΕΙΝΑΙ ΥΠΟΛΟΓΙΣΜΕΝΗ ΣΕ m
    
DV_AFAL = []
DV_MANO = []
DV_SANT = []
DV_SAWI = []

for i in range(0,len(K_AFAL)):
    DV_AFAL.append(2*math.pi*K_AFAL[i])
    DV_MANO.append(2*math.pi*K_MANO[i])
    DV_SANT.append(2*math.pi*K_SANT[i])
    DV_SAWI.append(2*math.pi*K_SAWI[i])

    
    

SUM_DV_AFAL = []
SUM_DV_MANO = []
SUM_DV_SANT = []
SUM_DV_SAWI = []
    

for i in range(0,len(DV_AFAL)):
    sum_afal = 0
    sum_mano = 0
    sum_sant = 0
    sum_sawi = 0
    for j in range(0,i+2):
        if(i == last_day-(len(DateMiss)+3)):
            break
        sum_afal = sum_afal + DV_AFAL[j]
        sum_mano = sum_mano + DV_MANO[j]
        sum_sant = sum_sant + DV_SANT[j]
        sum_sawi = sum_sawi + DV_SAWI[j]
        
    
    SUM_DV_AFAL.append(sum_afal)
    SUM_DV_MANO.append(sum_mano)
    SUM_DV_SANT.append(sum_sant)
    SUM_DV_SAWI.append(sum_sawi)
    

        
#ΔΙΑΒΑΣΜΑ ΑΡΧΕΙΟΥ ΗΜΕΡΩΝ
if(len(Dates)>=3):
    _, *Dates, _ = Dates  

figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, AFAL, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DS (ΣΕ m )', fontsize = 15)
# giving a title to my graph
plt.title('AFAL' , fontsize = 25)

#plt.xticks(Date2, Dates)

plt.legend()
 
# function to show the plot
plt.show()
    
      
#DateMiss
#Dates
# Out:
# Dwse Prwth mera: 1
# Dwse Teleutaia mera: 355

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, MANO, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DS (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('MANO' , fontsize = 25)

#plt.xticks(Date2, Dates)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, SANT, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DS (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('SANT' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, SAWI, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DS (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('SAWI' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, DV_AFAL, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('ΜΕΤΑΒΟΛΗ ΤΟΥ ΟΓΚΟΥ ME ΠΑΡΑΤΗΡΗΣΕΙΣ ΑΠΟ ΤΟΝ ΣΤΑΘΜΟ AFAL' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, DV_MANO, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('ΜΕΤΑΒΟΛΗ ΤΟΥ ΟΓΚΟΥ ME ΠΑΡΑΤΗΡΗΣΕΙΣ ΑΠΟ ΤΟΝ ΣΤΑΘΜΟ MANO' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, DV_SANT, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('ΜΕΤΑΒΟΛΗ ΤΟΥ ΟΓΚΟΥ ME ΠΑΡΑΤΗΡΗΣΕΙΣ ΑΠΟ ΤΟΝ ΣΤΑΘΜΟ SANT' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, DV_SAWI, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('ΜΕΤΑΒΟΛΗ ΤΟΥ ΟΓΚΟΥ ME ΠΑΡΑΤΗΡΗΣΕΙΣ ΑΠΟ ΤΟΝ ΣΤΑΘΜΟ SAWI' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, SUM_DV_AFAL, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('SUM_DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('SUM DV AFAL' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, SUM_DV_MANO, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('SUM_DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('SUM DV MANO' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, SUM_DV_SANT, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('SUM_DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('SUM DV SANT' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
figure(figsize=(30, 10), dpi=100)
# plotting the points
plt.plot(Dates, SUM_DV_SAWI, 'go-', label = 'File Data')
 
# naming the x axis
plt.xlabel('Day', fontsize = 15)
# naming the y axis
plt.ylabel('SUM_DV (ΣΕ m)', fontsize = 15)
# giving a title to my graph
plt.title('SUM DV SAWI' , fontsize = 25)

#plt.xticks(Date2, Date)

plt.legend()
 
# function to show the plot
plt.show()

# %%
len(DateMiss)
# Out:
# 16
